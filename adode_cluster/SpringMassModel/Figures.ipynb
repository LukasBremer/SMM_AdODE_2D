# %%
import matplotlib.pyplot as plt
import numpy as np
import h5py
from HelperAndMechanics import *
from matplotlib import cm
from ipywidgets import *
# Set Palatino as the default font
font = {'family': 'serif', 'serif': ['Palatino'], 'size': 20}
plt.rc('font', **font)
plt.rc('text', usetex=True)

# %% [markdown]
# ### Show dynamic of Alief Panvielov

# %%
"""
    Reads in necessary parameters from config.ini
"""
N,size,[] = read_config([],mode = 'chaos')

# Load from HDF5
with h5py.File('../data/SpringMassModel/MechanicalData/data_eta_05_uv.h5', 'r') as f:
    dA = f['dA'][:]
    u = f['u'][:]
    T = f['T'][:]
    v = f['v'][:]
    f.close()
N = T.shape[0]

# %%
#normalize data to 1
u = u
v = v
T = T
dA = dA

u_plot = u[:,50,50]/np.max(u)
v_plot = v[:,50,50]/np.max(v)
T_plot = T[:,50,50]/np.max(T)
dA_plot = dA[:,50,50]/np.max(dA)

t_au = np.linspace(0, 1, N)

# %%
# Plotting
plt.figure(figsize=(12, 6)) 
# plt.plot(t_au,T_plot, label='$T_a$')
plt.plot(t_au,u_plot, label='$u$')
plt.plot(t_au,v_plot, label='$v$')
plt.xlabel('Time in [a.u.]')
plt.ylabel('Amplitude in [a.u.]')
plt.legend()
plt.title('Dynamic of Aliev-Panfilov Model')

# plt.savefig('../../figures/theory/AP_uv.png')
# Out:
# Text(0.5, 1.0, 'Dynamic of Aliev-Panfilov Model')

# %%
# Plotting
plt.figure(figsize=(12, 6)) 
plt.plot(t_au,u_plot, label='$u$')
plt.plot(t_au,v_plot, label='$v$')
plt.plot(t_au,T_plot, label='$T_a$')
plt.xlabel('Time in [a.u.]')
plt.ylabel('Amplitude in [a.u.]')
plt.legend()
plt.title('Dynamic of Aliev-Panfilov Model')
plt.grid()
# plt.savefig('../../figures/theory/AP_uvT.png')

# %%
fig, ax = plt.subplots(1,2, figsize=(12, 6))
# Real eta0
im = ax[0].imshow(u[100], cmap='coolwarm')
ax[0].set_title('u')
ax[0].axes.xaxis.set_visible(False)
ax[0].axes.yaxis.set_visible(False)
fig.colorbar(im, ax=ax[0])

im = ax[1].imshow(dA[100], cmap='coolwarm')
ax[1].set_title('$dA$')
ax[1].axes.xaxis.set_visible(False)
ax[1].axes.yaxis.set_visible(False)
fig.colorbar(im, ax=ax[1])

fig.suptitle('Reconstruction of Mechanical Volume Contraction by AdoptODE', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')
# plt.savefig('../../figures/theory/AP_uv_dA.png',dpi=300)
plt.show()

# %% [markdown]
# ## Results from full Domain

# %%
import h5py

def list_h5_structure(file_path):
    '''Recursively lists all groups, datasets, and attributes in an HDF5 file'''
    
    def print_structure(name, obj):
        indent = '  ' * name.count('/')
        if isinstance(obj, h5py.Group):
            print(f"{indent}📂 Group: {name}")
            # for key, value in obj.attrs.items():
            #     print(f"{indent}  └── 🏷️  Attribute: {key} = {value}")
        # elif isinstance(obj, h5py.Dataset):
            # print(f"{indent}📄 Dataset: {name} - shape: {obj.shape}, dtype: {obj.dtype}")
    
    with h5py.File(file_path, 'r') as f:
        print(f"📁 HDF5 File: {file_path}")
        f.visititems(print_structure)

def load_run(file_path, run):
    '''Reads the data and parameters from a saved HDF5 file'''
    
    data = {}  # Dictionary to store datasets
    params_dict = {}  # Dictionary to store parameters
    
    with h5py.File(file_path, 'r') as f:
        if run not in f:
            raise ValueError(f"Run '{run}' not found in file.")
        
        group = f[run]  # Access the group corresponding to the given 'run'
        
        # Load all datasets (convert to NumPy arrays)
        for key in ['u_sol', 'u', 'v_sol', 'v', 'T_sol', 'T', 'x_sol', 'x','u_BOCF','v_BOCF','T_BOCF','x_BOCF','losses']:
            if key in group:
                data[key] = np.array(group[key])  # Convert dataset to NumPy array
        
        # Load parameter attributes from 'params_train' subgroup
        if "params_train" in group:
            params_group = group["params_train"]
            for key in params_group.attrs:
                params_dict[key] = params_group.attrs[key]  # Store as dictionary
    
    return data, params_dict

# %%
file_path = '../data/SpringMassModel/EtaSweep/FullDomain_len15_lr15_tol099_keepdataTrue_keepparamsTrue_etavarFalse_modechaos.h5'

run = 'run0'

list_h5_structure(file_path)

data, params_train = load_run(file_path, run)
# Accessing the datasets
u_sol = data['u_sol'][0]
u_sim = data['u'][0]
v_sol = data['v_sol'][0]
v_sim = data['v'][0]
T_sol = data['T_sol'][0]
T_sim = data['T'][0]
x_sol = data['x_sol'][0]
x_sim = data['x'][0]
losses = data['losses']

# u_BOCF = data['u_BOCF'][0]
# v_BOCF = data['v_BOCF'][0]
# T_BOCF = data['T_BOCF'][0]
# x_BOCF = data['x_BOCF'][0]
# u_sol = data['u_sol'][0]
# v_sol = data['v_sol'][0]
# T_sol = data['T_sol'][0]
# x_sol = data['x_sol'][0]

plt.plot(np.linspace(0,len(losses)*10,len(losses)),np.log(losses))
# Out:
# 📁 HDF5 File: ../data/SpringMassModel/EtaSweep/FullDomain_len15_lr15_tol099_keepdataTrue_keepparamsTrue_etavarFalse_modechaos.h5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 7
#       3 run = 'run0'
#       5 list_h5_structure(file_path)
# ----> 7 data, params_train = load_run(file_path, run)
#       8 # Accessing the datasets
#       9 u_sol = data['u_sol'][0]
#
# Cell In[7], line 27, in load_run(file_path, run)
#      25 with h5py.File(file_path, 'r') as f:
#      26     if run not in f:
# ---> 27         raise ValueError(f"Run '{run}' not found in file.")
#      29     group = f[run]  # Access the group corresponding to the given 'run'
#      31     # Load all datasets (convert to NumPy arrays)
#
# ValueError: Run 'run0' not found in file.

# %%
keys =['k_T','k_ij','k_ij_pad','k_j','k_a','k_a_pad','c_a','m','c_damp','n_0','l_0','spacing']
N,size,params_true = read_config(['k_T','k_ij','k_ij_pad','k_j','k_a','k_a_pad','c_a','m','c_damp','n_0','l_0','spacing'],mode = 'scroll')
params_true = dict(zip(keys,params_true))
# Get the parameter names
param_names = list(params_true.keys())
# Calculate the relative error for each parameter
relative_errors = []

for param_name in param_names:
    
    real_value = params_true.get(param_name, np.nan)
    train_value = params_train.get(param_name, np.nan)
    if np.isnan(real_value) or np.isnan(train_value):
        relative_errors.append(np.nan)
    else:
        relative_error = np.abs((train_value - real_value) / real_value)
        relative_errors.append(relative_error)
# Plot the relative errors
plt.figure(figsize=(16, 3))
plt.bar(param_names, relative_errors)
plt.xlabel('Parameter')
plt.ylabel('Relative Error')
plt.title('Relative Error of Parameters')
plt.xticks(rotation=45)
plt.show()

# %%
# vmin,vmax =  0,1
pad = 10

# Function to update the plot
def update_plot(frame):
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))  # Create 2 side-by-side subplots
    
    # Plot dA_fit
    im1 = axes[0].matshow(u_sol[frame], cmap='coolwarm',vmin=0, vmax=1)
    # im1 = axes[0].matshow(dA_rec[frame, pad:-pad, pad:-pad], cmap='coolwarm', vmin=vmin, vmax=vmax)
    axes[0].set_title(f"Reconstructed T (AP)")
    
    # Plot dA_sim
    im2 = axes[1].matshow(u_sim[frame], cmap='coolwarm',vmin=0, vmax=1)
    # im2 = axes[1].matshow(dA_sim[frame, pad:-pad, pad:-pad], cmap='coolwarm', vmin=vmin, vmax=vmax)
    axes[1].set_title(f"Simulated T (AP)")
    
    # Add colorbars
    fig.colorbar(im1, ax=axes[0])
    fig.colorbar(im2, ax=axes[1])

    plt.show()
def update_single_plot(frame):
    fig,axes = plt.subplots(1, 1, figsize=(10,8))

    # Plot dA_fit
    im1 = axes.matshow(u_BOCF[frame], cmap='coolwarm')
    # im1 = axes.matshow(dA_err[frame, pad:-pad, pad:-pad], cmap='coolwarm', vmin=vmin, vmax=vmax)
    axes.set_title(f"dA error")

    # Add colorbars
    # fig.colorbar(im1, ax=axes)

    plt.show()

# Create interactive slider
frame_slider = widgets.IntSlider(min=0, max=u_sol.shape[0]-1, step=1, value=0, description="Frame")

# Use interactive_output instead of interactive
out = widgets.interactive_output(update_plot, {'frame': frame_slider})

# Display slider and output
display(frame_slider, out)
# Out:
# IntSlider(value=0, description='Frame', max=34)
# Output()

# %%
# Plotting
fig, ax = plt.subplots(1,2, figsize=(12, 6))
frame = -1
# Real eta0
dA_sol = compute_dA(x_sol,1)[:,pad:-pad,pad:-pad]
dA_sim = compute_dA(x_sim,1)[:,pad:-pad,pad:-pad]
dA_err = np.abs(dA_sim-dA_sol)
im = ax[0].imshow(dA_sim[frame], cmap='coolwarm')
ax[0].set_title('Simulated $dA$')
ax[0].axes.xaxis.set_visible(False)
ax[0].axes.yaxis.set_visible(False)
fig.colorbar(im, ax=ax[0])

# im = ax[1].imshow(dA_err[frame]/np.max(dA_err[frame]), cmap='coolwarm')
im = ax[1].imshow(dA_sol[frame], cmap='coolwarm')
ax[1].set_title('Reconstructed $dA$')
ax[1].axes.xaxis.set_visible(False)
ax[1].axes.yaxis.set_visible(False)
fig.colorbar(im, ax=ax[1])

fig.suptitle('Reconstruction of Mechanical Volume Contraction by AdoptODE', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')

# plt.savefig('../../figures/results/reconstrunct_dA_full_domain.png',dpi=300)
# Out:
# 2025-04-22 09:53:28.749858: W external/xla/xla/service/gpu/nvptx_compiler.cc:765] The NVIDIA driver's CUDA version is 12.2 which is older than the ptxas CUDA version (12.8.61). Because the driver is older than the ptxas version, XLA is disabling parallel compilation, which may slow down compilation. You should update your NVIDIA driver or use the NVIDIA-provided CUDA forward compatibility packages.
# Text(0.5, 0.98, 'Reconstruction of Mechanical Volume Contraction by AdoptODE')

# %%
# Plotting
fig, ax = plt.subplots(1,2, figsize=(12, 6))
frame = 10
# Real eta0
im = ax[0].imshow(u_sol[frame], cmap='coolwarm')
ax[0].set_title('Reconstructed $u$')
ax[0].axes.xaxis.set_visible(False)
ax[0].axes.yaxis.set_visible(False)
# fig.colorbar(im, ax=ax[0])

im = ax[1].imshow(u_sim[frame] , cmap='coolwarm')
ax[1].set_title('Simulated $u$')
ax[1].axes.xaxis.set_visible(False)
ax[1].axes.yaxis.set_visible(False)

# fig.colorbar(im, ax=ax[1])

fig.suptitle('Reconstruction of electric activity by AdoptODE', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')

# plt.savefig('../../figures/results/reconstrunct_u_full_domain.png',dpi=300)
# Out:
# Text(0.5, 0.98, 'Reconstruction of electric activity by AdoptODE')

# %%
n_dist = np.load('../data/SpringMassModel/FiberOrientation/fiber_orientation.npy')
n_dist_train = sum_gaussian(3,params_train)
n_err = np.abs(n_dist-n_dist_train)
n_points = n_dist.shape[0]
y = np.linspace(-1, 1, n_points)

X, Y = np.meshgrid(y, y)

# Generate basis function centers
n_gaussians = 3  # Number of Gaussian basis functions
centers = np.linspace(-1, 1, n_gaussians)
sigma = 1  # Fixed width for all Gaussians

# Create a design matrix of Gaussian basis functions
def basis_matrix(X, Y, centers, sigma):
    features = []
    for x0 in centers:
        for y0 in centers:
            features.append(gaussian_2d(x0, y0, 1).flatten())  # Amplitude = 1 for now
    return np.array(features).T  # Shape (N_samples, N_basis)

# Compute basis functions for given centers
Phi = basis_matrix(X, Y, centers, sigma)

# Solve for weights using least squares regression
coeffs, _, _, _ = np.linalg.lstsq(Phi, n_dist.flatten(), rcond=None)
params_gaussian = coeffs_to_params(coeffs)

# Reconstruct the field using the fitted coefficients
reconstructed = Phi @ coeffs
reconstructed = reconstructed.reshape(n_points, n_points)
reconstructed = sum_gaussian(n_gaussians,params_gaussian)
# Plot results

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].imshow(n_dist, cmap='viridis', origin='lower',vmin=np.min(n_dist), vmax=np.max(n_dist))
axes[0].set_title("Original Scalar Field")
plt.colorbar(axes[0].imshow(n_dist, cmap='viridis', origin='lower'))   

axes[1].imshow(n_dist_train, cmap='viridis', origin='lower',vmin=np.min(n_dist), vmax=np.max(n_dist))

axes[1].set_title("reconstruction")
plt.colorbar(axes[1].imshow(n_dist_train, cmap='viridis', origin='lower'))


plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 2
#       1 n_dist = np.load('../data/SpringMassModel/FiberOrientation/fiber_orientation.npy')
# ----> 2 n_dist_train = sum_gaussian(3,params_train)
#       3 n_err = np.abs(n_dist-n_dist_train)
#       4 n_points = n_dist.shape[0]
#
#     [... skipping hidden 11 frame]
#
# File /data.bmp/lbremer/Master_thesis/Projectfolder/adoptODE_smmodell/adode_cluster/SpringMassModel/HelperAndMechanics/MechanicsFullDomain.py:392, in sum_gaussian(n_gaussians, params, sigma)
#     390 for x0 in range(3):
#     391     for y0 in range(3):
# --> 392         sum += gaussian_2d(centers[x0], centers[y0], params['Amp'+str(x0)+str(y0)], sigma)
#     394 return sum
#
# KeyError: 'Amp00'

# %%
#calculate the Mean squared error of n_dist and n_dist_train
rmse = np.sqrt(np.mean((n_dist - n_dist_train)**2))
print(f"RMSE: {rmse}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 #calculate the Mean squared error of n_dist and n_dist_train
# ----> 2 rmse = np.sqrt(np.mean((n_dist - n_dist_train)**2))
#       3 print(f"RMSE: {rmse}")
#
# NameError: name 'n_dist_train' is not defined

# %%
i,j = 50,50

dA_test = dA[:,i,j]
T_test = T[:,i,j]
maxima_temp0, _ = find_peaks(dA_test,prominence=.0007)#,height=.001
minima_temp0, _ = find_peaks(-dA_test,prominence=.0007)#,height=.001
max_indx, min_indx = index_finder(maxima_temp0, minima_temp0, dA_test,start_indx=0)


# Plotting
plt.figure(figsize=(12, 7))

# Line plot of dA_test
plt.plot(t_au,dA_test/np.max(dA_test), label="$dA$")

# Scatter plot for maxima (red) and minima (green)
plt.scatter(t_au[maxima_temp0], dA_test[maxima_temp0]/np.max(dA_test), c='r', label="max")
plt.scatter(t_au[minima_temp0], dA_test[minima_temp0]/np.max(dA_test), c='g', label="min")

# Get y-axis limits
y_min, y_max = plt.ylim()

# Fill entire y-direction between specified maximum and minimum indices
plt.fill_between(
    [(t_au[maxima_temp0[max_indx]]), (t_au[minima_temp0[min_indx]])],
    y_min,  # Fill from the bottom of the y-axis
    y_max,  # Fill to the top of the y-axis
    alpha=0.2,
    color='blue',
    label="detected peak"
)

# Plot scaled T_test
plt.plot(t_au,T_test / np.max(T_test), label="$T$")

# Add labels, legend, and grid
plt.xlabel("Time in a.u.")
plt.ylabel("Amplitude in a.u.")
plt.title("MSD; find $T_a$-peak based on $dA$ maxima and minima")
plt.legend(loc='upper right')
#plt.grid(alpha=0.5)


# plt.savefig('../../figures/Methods/MSD_peak_finder.png')
plt.show()

# %%
T_standard = np.load('../data/SpringMassModel/StandardPeaks/T_standard1.npy')
delta_t = .01
t_evals = np.linspace(0,N*delta_t,N)
t_standard = np.linspace(0,len(T_standard)*delta_t,len(T_standard))

t_start = maxima_temp0[max_indx]
t_stop = minima_temp0[min_indx]
t_peak_start = t_evals[maxima_temp0[max_indx]]
t_peak_stop = t_evals[minima_temp0[min_indx]]
t_evals_start = t_evals[maxima_temp0[max_indx]]

# %%
Delta_t_peak = t_peak_stop- t_peak_start
Delta_t_standard = len(T_standard)*delta_t

T_strecht, t_stretch = stretch_peak(Delta_t_peak, t_evals[t_start:t_stop], delta_t, T_standard, Delta_t_standard)
T_shifted = shift_peak(t_peak_start, t_evals_start, T_strecht)
print(len(T_strecht), len(t_stretch), len(T_shifted))
# Out:
# E0422 11:35:42.197355  154695 pjrt_stream_executor_client.cc:2985] Execution of replica 0 failed: INTERNAL: CustomCall failed: jaxlib/gpu/solver_kernels.cc:45: operation gpusolverDnCreate(&handle) failed: cuSolver internal error
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[39], line 4
#       1 Delta_t_peak = t_peak_stop- t_peak_start
#       2 Delta_t_standard = len(T_standard)*delta_t
# ----> 4 T_strecht, t_stretch = stretch_peak(Delta_t_peak, t_evals[t_start:t_stop], delta_t, T_standard, Delta_t_standard)
#       5 T_shifted = shift_peak(t_peak_start, t_evals_start, T_strecht)
#       6 print(len(T_strecht), len(t_stretch), len(T_shifted))
#
# File /data.bmp/lbremer/Master_thesis/Projectfolder/adoptODE_smmodell/adode_cluster/SpringMassModel/HelperAndMechanics/ActiveStressPeak.py:19, in stretch_peak(Delta_t_peak, t_evals, delta_t, T_standard, Delta_t_standard)
#      16 alpha = Delta_t_peak/Delta_t_standard
#      18 t_standard = np.linspace(0,len(T_standard)*delta_t,len(T_standard))
# ---> 19 T_interp = interpax.CubicSpline(t_standard,T_standard)
#      21 t_stretch = np.linspace(0,len(T_standard)*delta_t,len(t_evals))
#      24 return T_interp(t_stretch) * alpha, t_stretch
#
#     [... skipping hidden 3 frame]
#
# File /data.bmp/lbremer/Master_thesis/Projectfolder/adoptODE_smmodell/.myvenv/lib/python3.9/site-packages/interpax/_ppoly.py:804, in CubicSpline.__init__(self, x, y, axis, bc_type, extrapolate, check)
#     794 def __init__(
#     795     self,
#     796     x: jax.Array,
#    (...)
#     801     check: bool = True,
#     802 ):
#     803     x, _, y, axis, _ = prepare_input(x, y, axis, check=check)
# --> 804     df = approx_df(x, y, "cubic2", axis, bc_type=bc_type)
#     805     super().__init__(x, y, df, axis=axis, extrapolate=extrapolate, check=check)
#
# File /data.bmp/lbremer/Master_thesis/Projectfolder/adoptODE_smmodell/.myvenv/lib/python3.9/site-packages/interpax/_fd_derivs.py:47, in approx_df(x, f, method, axis, **kwargs)
#      44 def fun(x, f):
#      45     return _approx_df(x, f, method, axis, **kwargs)
# ---> 47 return jit(fun)(x, f)
#
#     [... skipping hidden 10 frame]
#
# File /data.bmp/lbremer/Master_thesis/Projectfolder/adoptODE_smmodell/.myvenv/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:1253, in ExecuteReplicated.__call__(self, *args)
#    1251   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1252 else:
# -> 1253   results = self.xla_executable.execute_sharded(input_bufs)
#    1255 if dispatch.needs_check_special():
#    1256   out_arrays = results.disassemble_into_single_device_arrays()
#
# XlaRuntimeError: INTERNAL: CustomCall failed: jaxlib/gpu/solver_kernels.cc:45: operation gpusolverDnCreate(&handle) failed: cuSolver internal error

# %%
# Create a figure with two subplots
fig, axes = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# First subplot
axes[0].plot(t_evals[0:minima_temp0[min_indx] + 80], dA_test[0:minima_temp0[min_indx] + 80] * 200, label='dA')
axes[0].plot(t_standard, T_standard, label='$T_a$-stencil')
axes[0].scatter([t_standard[0], t_standard[-1]], [T_standard[0], T_standard[-1]], c='r')
axes[0].axvline(x=t_evals[t_start], color='k', linestyle='--', alpha=0.5)
axes[0].axvline(x=t_evals[t_stop], color='k', linestyle='--', alpha=0.5)
axes[0].set_ylabel("Amplitude in a.u.")
axes[0].legend(bbox_to_anchor=(1.01, 1), loc='upper left')
axes[0].set_title("Calibrating $T_a$-peak based on $dA$-max and min")

# Second subplot
axes[1].plot(t_evals[0:minima_temp0[min_indx] + 80], dA_test[0:minima_temp0[min_indx] + 80] * 200, label='dA')
axes[1].plot(t_evals[maxima_temp0[max_indx]:minima_temp0[min_indx]], T_shifted, label='Calibrated $T_a$-stencil')
axes[1].plot(t_standard, T_standard, color='grey', alpha=.5, linestyle='--', label='$T_a$-stencil')
axes[1].axvline(x=t_evals[t_start], color='k', linestyle='--', alpha=0.5)
axes[1].axvline(x=t_evals[t_stop], color='k', linestyle='--', alpha=0.5)
axes[1].set_xlabel("Time in a.u.")
axes[1].set_ylabel("Amplitude in a.u.")
axes[1].legend(bbox_to_anchor=(1.01, 1), loc='upper left')
axes[1].scatter([t_evals[maxima_temp0[max_indx]], t_evals[minima_temp0[min_indx]]], [T_shifted[0], T_shifted[-1]], c='r')
# Add an arrow annotation pointing from "standard" to "adjusted"
# Choose a point on the "standard" line and an equivalent point on the "adjusted" line
arrow_start = (t_standard[400], T_standard[400])  # A point on the standard line
arrow_end = (t_evals[280], T_shifted[280]+.1)    # A corresponding point on the adjusted line

# Annotate with an arrow
axes[1].annotate(
    'Calibration',                      # Annotation text
    xy=arrow_end,                      # Arrow tip (end)
    xytext=arrow_start,                # Text location (start)
    arrowprops=dict(facecolor='blue', arrowstyle='->', lw=1.5),  # Arrow style
    fontsize=12,
    ha='center'
)

# Adjust layout for better spacing
plt.tight_layout()
# plt.savefig('../../figures/Methods/MSD_peak_adjustment.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       2 fig, axes = plt.subplots(2, 1, figsize=(12, 10), sharex=True)
#       4 # First subplot
# ----> 5 axes[0].plot(t_evals[0:minima_temp0[min_indx] + 80], dA_test[0:minima_temp0[min_indx] + 80] * 200, label='dA')
#       6 axes[0].plot(t_standard, T_standard, label='$T_a$-stencil')
#       7 axes[0].scatter([t_standard[0], t_standard[-1]], [T_standard[0], T_standard[-1]], c='r')
#
# NameError: name 'minima_temp0' is not defined

# %% [markdown]
# ### analyze eta sweep

# %%
params_sweep_eta05 = np.load('../data/SpringMassModel/EtaSweep/eta_sweepT_rec_xl_eta05_0.npy',allow_pickle=True)
print(params_sweep_eta05.shape)
params_train_sweep_eta05 = params_sweep_eta05[:,:,0]
params_sweep_var = np.load('../data/SpringMassModel/EtaSweep/eta_sweepT_rec_xl_var_0.npy',allow_pickle=True)
params_sweep_var = np.load('../data/SpringMassModel/EtaSweep/eta_sweepnew.npy',allow_pickle=True)
params_train_sweep_var = params_sweep_var[:,:,0]
print(params_train_sweep_var)
# Out:
# (10, 10, 2)
# [[{'key': nan} {'key': nan}
#   {'c_a': Array(15.066799, dtype=float32), 'eta0': Array(0.47057495, dtype=float32), 'eta1': Array(0.7998856, dtype=float32), 'eta2': Array(0.22445557, dtype=float32), 'eta3': Array(0.9999707, dtype=float32), 'k_a': Array(3.9342089, dtype=float32), 'k_g': Array(8.068203, dtype=float32), 'k_p': Array(2.4952414, dtype=float32), 'l_g': Array(1.846092, dtype=float32), 'm': Array(0.6021329, dtype=float32), 'nu': Array(13.169612, dtype=float32)}
#   {'c_a': Array(10.374077, dtype=float32), 'eta0': Array(0.91657645, dtype=float32), 'eta1': Array(0.38847446, dtype=float32), 'eta2': Array(0.9673731, dtype=float32), 'eta3': Array(0.39098492, dtype=float32), 'k_a': Array(9.039767, dtype=float32), 'k_g': Array(6.994663, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03084848, dtype=float32), 'nu': Array(16.824282, dtype=float32)}
#   {'c_a': Array(13.485323, dtype=float32), 'eta0': Array(0.01888791, dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(0.03486007, dtype=float32), 'eta3': Array(0.05437098, dtype=float32), 'k_a': Array(2.9266903, dtype=float32), 'k_g': Array(13.850095, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03014197, dtype=float32), 'nu': Array(17.391428, dtype=float32)}
#   {'c_a': Array(0.80900717, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.999014, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0.9988171, dtype=float32), 'k_a': Array(2.3145936, dtype=float32), 'k_g': Array(13.474977, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.018877, dtype=float32), 'nu': Array(11.865208, dtype=float32)}
#   {'c_a': Array(15.279266, dtype=float32), 'eta0': Array(0.99670684, dtype=float32), 'eta1': Array(1., dtype=float32), 'eta2': Array(0.9986772, dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(5.55776, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03995355, dtype=float32), 'nu': Array(22.39783, dtype=float32)}
#   {'c_a': Array(17.19273, dtype=float32), 'eta0': Array(0.5503402, dtype=float32), 'eta1': Array(0.69027376, dtype=float32), 'eta2': Array(0.49028736, dtype=float32), 'eta3': Array(0.67614466, dtype=float32), 'k_a': Array(4.9219246, dtype=float32), 'k_g': Array(17.222448, dtype=float32), 'k_p': Array(1.5230203, dtype=float32), 'l_g': Array(1.7391816, dtype=float32), 'm': Array(2., dtype=float32), 'nu': Array(6.600549, dtype=float32)}
#   {'c_a': Array(8.026873, dtype=float32), 'eta0': Array(0.99836254, dtype=float32), 'eta1': Array(0.9989933, dtype=float32), 'eta2': Array(0.9985743, dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(17.59342, dtype=float32), 'k_g': Array(18.033855, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03290973, dtype=float32), 'nu': Array(16.874855, dtype=float32)}
#   {'c_a': Array(0., dtype=float32), 'eta0': Array(0.6886234, dtype=float32), 'eta1': Array(0.6935399, dtype=float32), 'eta2': Array(0.6946785, dtype=float32), 'eta3': Array(0.69175535, dtype=float32), 'k_a': Array(5.249647, dtype=float32), 'k_g': Array(18.92471, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03443449, dtype=float32), 'nu': Array(16.051964, dtype=float32)}]
#  [{'c_a': Array(20., dtype=float32), 'eta0': Array(0.581817, dtype=float32), 'eta1': Array(0.3718212, dtype=float32), 'eta2': Array(0.7558229, dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(6.966926, dtype=float32), 'k_g': Array(19.018969, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0.73518556, dtype=float32), 'm': Array(0.03064059, dtype=float32), 'nu': Array(20.89003, dtype=float32)}
#   {'c_a': Array(12.736873, dtype=float32), 'eta0': Array(0.7425877, dtype=float32), 'eta1': Array(0.0197676, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0.21249114, dtype=float32), 'k_a': Array(15.136722, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(0., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.01808272, dtype=float32), 'nu': Array(13.541154, dtype=float32)}
#   {'key': nan}
#   {'c_a': Array(14.96122, dtype=float32), 'eta0': Array(0.7399353, dtype=float32), 'eta1': Array(0.7978733, dtype=float32), 'eta2': Array(0.78274053, dtype=float32), 'eta3': Array(0.6581172, dtype=float32), 'k_a': Array(6.503739, dtype=float32), 'k_g': Array(12.787595, dtype=float32), 'k_p': Array(0., dtype=float32), 'l_g': Array(0.03091888, dtype=float32), 'm': Array(0.17847052, dtype=float32), 'nu': Array(0.28345117, dtype=float32)}
#   {'c_a': Array(1.8793483, dtype=float32), 'eta0': Array(0.99045897, dtype=float32), 'eta1': Array(0.1118334, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0.03372221, dtype=float32), 'k_a': Array(11.97194, dtype=float32), 'k_g': Array(22.213127, dtype=float32), 'k_p': Array(0., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03996505, dtype=float32), 'nu': Array(21.618492, dtype=float32)}
#   {'c_a': Array(13.484037, dtype=float32), 'eta0': Array(0.9847769, dtype=float32), 'eta1': Array(0.9963014, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(18., dtype=float32), 'k_g': Array(17.758339, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03052903, dtype=float32), 'nu': Array(21.60884, dtype=float32)}
#   {'c_a': Array(0., dtype=float32), 'eta0': Array(0.37876627, dtype=float32), 'eta1': Array(0.5240081, dtype=float32), 'eta2': Array(0.49566528, dtype=float32), 'eta3': Array(0.264123, dtype=float32), 'k_a': Array(10.606763, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(0.73711175, dtype=float32), 'l_g': Array(0.19106227, dtype=float32), 'm': Array(0.41149417, dtype=float32), 'nu': Array(0.9639977, dtype=float32)}
#   {'c_a': Array(4.2936306, dtype=float32), 'eta0': Array(0.68818563, dtype=float32), 'eta1': Array(0.9173371, dtype=float32), 'eta2': Array(0.63799644, dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(8.974201, dtype=float32), 'k_g': Array(9.178788, dtype=float32), 'k_p': Array(3.7481787, dtype=float32), 'l_g': Array(0.5991858, dtype=float32), 'm': Array(0.16138782, dtype=float32), 'nu': Array(0.13406673, dtype=float32)}
#   {'c_a': Array(8.174975, dtype=float32), 'eta0': Array(0., dtype=float32), 'eta1': Array(0.19071317, dtype=float32), 'eta2': Array(0.22538826, dtype=float32), 'eta3': Array(0.1309901, dtype=float32), 'k_a': Array(16.050543, dtype=float32), 'k_g': Array(14.696966, dtype=float32), 'k_p': Array(3.857071, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02151037, dtype=float32), 'nu': Array(8.919867, dtype=float32)}
#   {'c_a': Array(15.073378, dtype=float32), 'eta0': Array(0.8390177, dtype=float32), 'eta1': Array(0.03902672, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0.22428831, dtype=float32), 'k_a': Array(18., dtype=float32), 'k_g': Array(20.312656, dtype=float32), 'k_p': Array(0., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03222293, dtype=float32), 'nu': Array(19.716845, dtype=float32)}]
#  [{'key': nan}
#   {'c_a': Array(0.10472362, dtype=float32), 'eta0': Array(0.3531598, dtype=float32), 'eta1': Array(0.20875965, dtype=float32), 'eta2': Array(0., dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(13.696787, dtype=float32), 'k_g': Array(16.692839, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02378551, dtype=float32), 'nu': Array(14.6810255, dtype=float32)}
#   {'c_a': Array(16.100498, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.02734444, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(18., dtype=float32), 'k_g': Array(14.664133, dtype=float32), 'k_p': Array(0., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02335599, dtype=float32), 'nu': Array(17.628836, dtype=float32)}
#   {'c_a': Array(13.054594, dtype=float32), 'eta0': Array(0.40261483, dtype=float32), 'eta1': Array(0.8254344, dtype=float32), 'eta2': Array(0.16592091, dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(10.981215, dtype=float32), 'k_g': Array(20.203917, dtype=float32), 'k_p': Array(2.753516, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.29862943, dtype=float32), 'nu': Array(2.2958584, dtype=float32)}
#   {'c_a': Array(12.153174, dtype=float32), 'eta0': Array(0.5766402, dtype=float32), 'eta1': Array(0.57977235, dtype=float32), 'eta2': Array(0.648181, dtype=float32), 'eta3': Array(0.62723607, dtype=float32), 'k_a': Array(1.500881, dtype=float32), 'k_g': Array(12.428599, dtype=float32), 'k_p': Array(2.278386, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.2548446, dtype=float32), 'nu': Array(0.18101338, dtype=float32)}
#   {'c_a': Array(13.373596, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.39653718, dtype=float32), 'eta2': Array(0.9969893, dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(15.76296, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03641509, dtype=float32), 'nu': Array(18.677008, dtype=float32)}
#   {'c_a': Array(8.465876, dtype=float32), 'eta0': Array(0.8882578, dtype=float32), 'eta1': Array(0.8234344, dtype=float32), 'eta2': Array(0.87583864, dtype=float32), 'eta3': Array(0.9291403, dtype=float32), 'k_a': Array(5.865414, dtype=float32), 'k_g': Array(24.393711, dtype=float32), 'k_p': Array(2.8959458, dtype=float32), 'l_g': Array(0.00167678, dtype=float32), 'm': Array(0.5168649, dtype=float32), 'nu': Array(0.03957409, dtype=float32)}
#   {'c_a': Array(9.320643, dtype=float32), 'eta0': Array(0.3834136, dtype=float32), 'eta1': Array(0.38531682, dtype=float32), 'eta2': Array(0.400537, dtype=float32), 'eta3': Array(0.38744682, dtype=float32), 'k_a': Array(17.244545, dtype=float32), 'k_g': Array(17.592924, dtype=float32), 'k_p': Array(1.2213242, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.01897976, dtype=float32), 'nu': Array(3.9968023, dtype=float32)}
#   {'c_a': Array(0.3083654, dtype=float32), 'eta0': Array(0.7886726, dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0.14013359, dtype=float32), 'k_a': Array(13.7832575, dtype=float32), 'k_g': Array(5.371656, dtype=float32), 'k_p': Array(0.62195086, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.0324776, dtype=float32), 'nu': Array(13.361322, dtype=float32)}
#   {'c_a': Array(20., dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.01873647, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(7.9526563, dtype=float32), 'k_g': Array(19.13797, dtype=float32), 'k_p': Array(1.5583401, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03641514, dtype=float32), 'nu': Array(25.648977, dtype=float32)}]
#  [{'key': nan}
#   {'c_a': Array(12.256328, dtype=float32), 'eta0': Array(0.8497778, dtype=float32), 'eta1': Array(0.17554674, dtype=float32), 'eta2': Array(0.9406994, dtype=float32), 'eta3': Array(0.25635844, dtype=float32), 'k_a': Array(18., dtype=float32), 'k_g': Array(16.60196, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03034692, dtype=float32), 'nu': Array(18.387676, dtype=float32)}
#   {'c_a': Array(4.654834, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.65328485, dtype=float32), 'eta2': Array(0.9445957, dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(18., dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02855956, dtype=float32), 'nu': Array(8.842468, dtype=float32)}
#   {'c_a': Array(3.804142, dtype=float32), 'eta0': Array(0.14435098, dtype=float32), 'eta1': Array(0.9616303, dtype=float32), 'eta2': Array(0.11516768, dtype=float32), 'eta3': Array(0.9884725, dtype=float32), 'k_a': Array(8.253039, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(2.8308966, dtype=float32), 'l_g': Array(0.49539572, dtype=float32), 'm': Array(0.27122915, dtype=float32), 'nu': Array(0.382832, dtype=float32)}
#   {'c_a': Array(13.497484, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.12030351, dtype=float32), 'eta2': Array(0.99412227, dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(13.732977, dtype=float32), 'k_g': Array(18.44811, dtype=float32), 'k_p': Array(0.01883826, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03316697, dtype=float32), 'nu': Array(20.77035, dtype=float32)}
#   {'c_a': Array(4.0318093, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.40156665, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(15.703623, dtype=float32), 'k_g': Array(23.617344, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02654707, dtype=float32), 'nu': Array(18.280727, dtype=float32)}
#   {'c_a': Array(20., dtype=float32), 'eta0': Array(0.87419164, dtype=float32), 'eta1': Array(0.7628344, dtype=float32), 'eta2': Array(0.84436154, dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(2.0657969, dtype=float32), 'k_g': Array(22.647388, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.36397165, dtype=float32), 'nu': Array(4.2779493, dtype=float32)}
#   {'c_a': Array(0.01521951, dtype=float32), 'eta0': Array(0.7108057, dtype=float32), 'eta1': Array(0.71277714, dtype=float32), 'eta2': Array(0.71560335, dtype=float32), 'eta3': Array(0.71375257, dtype=float32), 'k_a': Array(9.038452, dtype=float32), 'k_g': Array(25.999666, dtype=float32), 'k_p': Array(3.8301911, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.6303789, dtype=float32), 'nu': Array(0.19570746, dtype=float32)}
#   {'c_a': Array(9.52792, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.14385387, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0.11459719, dtype=float32), 'k_a': Array(17.944548, dtype=float32), 'k_g': Array(17.70789, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02810213, dtype=float32), 'nu': Array(17.192873, dtype=float32)}
#   {'c_a': Array(11.123977, dtype=float32), 'eta0': Array(0., dtype=float32), 'eta1': Array(0.25046664, dtype=float32), 'eta2': Array(0.13253471, dtype=float32), 'eta3': Array(0.20736788, dtype=float32), 'k_a': Array(9.755245, dtype=float32), 'k_g': Array(22.637537, dtype=float32), 'k_p': Array(3.5622208, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03218004, dtype=float32), 'nu': Array(24.712414, dtype=float32)}]
#  [{'key': nan}
#   {'c_a': Array(13.55585, dtype=float32), 'eta0': Array(0., dtype=float32), 'eta1': Array(0.04079136, dtype=float32), 'eta2': Array(0., dtype=float32), 'eta3': Array(0.08153608, dtype=float32), 'k_a': Array(12.170961, dtype=float32), 'k_g': Array(25.985712, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02426938, dtype=float32), 'nu': Array(19.836315, dtype=float32)}
#   {'key': nan}
#   {'c_a': Array(0., dtype=float32), 'eta0': Array(0.6854362, dtype=float32), 'eta1': Array(0.63426214, dtype=float32), 'eta2': Array(0.630925, dtype=float32), 'eta3': Array(0.17083637, dtype=float32), 'k_a': Array(18., dtype=float32), 'k_g': Array(6.837723, dtype=float32), 'k_p': Array(3.4945123, dtype=float32), 'l_g': Array(0.10653527, dtype=float32), 'm': Array(0.13493578, dtype=float32), 'nu': Array(0.637388, dtype=float32)}
#   {'c_a': Array(12.462575, dtype=float32), 'eta0': Array(0., dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(0.7458525, dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(7.3481402, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(3.5769064, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03194558, dtype=float32), 'nu': Array(17.75561, dtype=float32)}
#   {'c_a': Array(13.382783, dtype=float32), 'eta0': Array(0., dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(0.62054896, dtype=float32), 'eta3': Array(0.08222543, dtype=float32), 'k_a': Array(10.730912, dtype=float32), 'k_g': Array(14.068438, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03597915, dtype=float32), 'nu': Array(17.940374, dtype=float32)}
#   {'c_a': Array(5.6454787, dtype=float32), 'eta0': Array(0.7275933, dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(6.745573, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02901668, dtype=float32), 'nu': Array(19.538681, dtype=float32)}
#   {'c_a': Array(0., dtype=float32), 'eta0': Array(0.64169616, dtype=float32), 'eta1': Array(0.64401287, dtype=float32), 'eta2': Array(0.6446357, dtype=float32), 'eta3': Array(0.64323634, dtype=float32), 'k_a': Array(0., dtype=float32), 'k_g': Array(17.05128, dtype=float32), 'k_p': Array(2.0405245, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.27137956, dtype=float32), 'nu': Array(0.1252468, dtype=float32)}
#   {'c_a': Array(20., dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.9978003, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(8.149967, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02173913, dtype=float32), 'nu': Array(17.623993, dtype=float32)}
#   {'c_a': Array(9.803255, dtype=float32), 'eta0': Array(0., dtype=float32), 'eta1': Array(0.00087969, dtype=float32), 'eta2': Array(0.05382453, dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(13.881426, dtype=float32), 'k_g': Array(22.403904, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.05096088, dtype=float32), 'nu': Array(21.786755, dtype=float32)}]
#  [{'key': nan}
#   {'c_a': Array(15.162731, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(12.37351, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(3.709386, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.00256256, dtype=float32), 'nu': Array(19.098999, dtype=float32)}
#   {'key': nan} {'key': nan}
#   {'c_a': Array(6.097258, dtype=float32), 'eta0': Array(0.50493914, dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(0.48749366, dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(14.34378, dtype=float32), 'k_g': Array(6.7817783, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03245432, dtype=float32), 'nu': Array(18.745815, dtype=float32)}
#   {'c_a': Array(14.595662, dtype=float32), 'eta0': Array(0.05414526, dtype=float32), 'eta1': Array(0.93720216, dtype=float32), 'eta2': Array(0.01736308, dtype=float32), 'eta3': Array(0.9984911, dtype=float32), 'k_a': Array(4.1263127, dtype=float32), 'k_g': Array(16.88672, dtype=float32), 'k_p': Array(3.9151812, dtype=float32), 'l_g': Array(0.00067679, dtype=float32), 'm': Array(0.2460148, dtype=float32), 'nu': Array(0., dtype=float32)}
#   {'c_a': Array(15.862887, dtype=float32), 'eta0': Array(0.33109656, dtype=float32), 'eta1': Array(0.33064884, dtype=float32), 'eta2': Array(0.3305246, dtype=float32), 'eta3': Array(0.33245376, dtype=float32), 'k_a': Array(0.05581878, dtype=float32), 'k_g': Array(12.679572, dtype=float32), 'k_p': Array(1.9042605, dtype=float32), 'l_g': Array(0.09891437, dtype=float32), 'm': Array(0.16270824, dtype=float32), 'nu': Array(0.03369096, dtype=float32)}
#   {'c_a': Array(1.8083535, dtype=float32), 'eta0': Array(0.99901706, dtype=float32), 'eta1': Array(0.9977493, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(0.09250144, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.38099885, dtype=float32), 'nu': Array(2.264692, dtype=float32)}
#   {'c_a': Array(13.402514, dtype=float32), 'eta0': Array(0., dtype=float32), 'eta1': Array(0.00612509, dtype=float32), 'eta2': Array(0.55792606, dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(11.541392, dtype=float32), 'k_g': Array(16.650272, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03595956, dtype=float32), 'nu': Array(21.6177, dtype=float32)}
#   {'key': nan}]
#  [{'c_a': Array(5.191084, dtype=float32), 'eta0': Array(0.72691035, dtype=float32), 'eta1': Array(0.71611416, dtype=float32), 'eta2': Array(0.7284284, dtype=float32), 'eta3': Array(0.6454931, dtype=float32), 'k_a': Array(12.206988, dtype=float32), 'k_g': Array(3.9413135, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02777538, dtype=float32), 'nu': Array(4.344548, dtype=float32)}
#   {'c_a': Array(4.1125593, dtype=float32), 'eta0': Array(0.63473976, dtype=float32), 'eta1': Array(1., dtype=float32), 'eta2': Array(0.78882307, dtype=float32), 'eta3': Array(0.7579916, dtype=float32), 'k_a': Array(4.6764116, dtype=float32), 'k_g': Array(21.193222, dtype=float32), 'k_p': Array(2.6017075, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.49060678, dtype=float32), 'nu': Array(0.2708187, dtype=float32)}
#   {'c_a': Array(4.2587266, dtype=float32), 'eta0': Array(0.4757093, dtype=float32), 'eta1': Array(0.62504816, dtype=float32), 'eta2': Array(0.5582484, dtype=float32), 'eta3': Array(0.76420873, dtype=float32), 'k_a': Array(3.8454134, dtype=float32), 'k_g': Array(8.131015, dtype=float32), 'k_p': Array(3.3900685, dtype=float32), 'l_g': Array(0.00149323, dtype=float32), 'm': Array(0.16103481, dtype=float32), 'nu': Array(0.02302087, dtype=float32)}
#   {'key': nan}
#   {'c_a': Array(15.776821, dtype=float32), 'eta0': Array(0.00396804, dtype=float32), 'eta1': Array(0.00931042, dtype=float32), 'eta2': Array(0., dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(0.6140315, dtype=float32), 'k_g': Array(24.564932, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(1.1047933, dtype=float32), 'm': Array(0.09489156, dtype=float32), 'nu': Array(0.31974047, dtype=float32)}
#   {'c_a': Array(19.868998, dtype=float32), 'eta0': Array(0.9185207, dtype=float32), 'eta1': Array(0.9195987, dtype=float32), 'eta2': Array(0.91596407, dtype=float32), 'eta3': Array(0.9149467, dtype=float32), 'k_a': Array(0., dtype=float32), 'k_g': Array(7.082766, dtype=float32), 'k_p': Array(1.0054946, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.13331622, dtype=float32), 'nu': Array(0.11068624, dtype=float32)}
#   {'c_a': Array(9.4433365, dtype=float32), 'eta0': Array(0.04613914, dtype=float32), 'eta1': Array(0.8675639, dtype=float32), 'eta2': Array(0.01963887, dtype=float32), 'eta3': Array(0.89059556, dtype=float32), 'k_a': Array(6.114654, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(3.185711, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.38965294, dtype=float32), 'nu': Array(0.1214994, dtype=float32)}
#   {'c_a': Array(15.395753, dtype=float32), 'eta0': Array(0., dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(0.01424729, dtype=float32), 'eta3': Array(0.01067908, dtype=float32), 'k_a': Array(11.057256, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03086513, dtype=float32), 'nu': Array(17.378805, dtype=float32)}
#   {'c_a': Array(0.00350697, dtype=float32), 'eta0': Array(0.76191694, dtype=float32), 'eta1': Array(0.8079485, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0.3860863, dtype=float32), 'k_a': Array(18., dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(0., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.52802426, dtype=float32), 'nu': Array(2.7497275, dtype=float32)}
#   {'c_a': Array(2.9772868, dtype=float32), 'eta0': Array(0.9359604, dtype=float32), 'eta1': Array(0.98468673, dtype=float32), 'eta2': Array(0.95703304, dtype=float32), 'eta3': Array(1., dtype=float32), 'k_a': Array(6.9880667, dtype=float32), 'k_g': Array(15.209853, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.01316761, dtype=float32), 'nu': Array(7.979603, dtype=float32)}]
#  [{'c_a': Array(11.675064, dtype=float32), 'eta0': Array(0.5508136, dtype=float32), 'eta1': Array(0.57206386, dtype=float32), 'eta2': Array(0.5765703, dtype=float32), 'eta3': Array(0.55647844, dtype=float32), 'k_a': Array(9.638355, dtype=float32), 'k_g': Array(25.151953, dtype=float32), 'k_p': Array(1.1176585, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.43959925, dtype=float32), 'nu': Array(1.2081441, dtype=float32)}
#   {'c_a': Array(14.095946, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0.12965722, dtype=float32), 'k_a': Array(16.083595, dtype=float32), 'k_g': Array(16.130674, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02973944, dtype=float32), 'nu': Array(10.740919, dtype=float32)}
#   {'c_a': Array(0.7179962, dtype=float32), 'eta0': Array(0.8888857, dtype=float32), 'eta1': Array(1., dtype=float32), 'eta2': Array(0.02116668, dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(9.104858, dtype=float32), 'k_g': Array(20.42676, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03335923, dtype=float32), 'nu': Array(22.988127, dtype=float32)}
#   {'c_a': Array(0.0554303, dtype=float32), 'eta0': Array(0.03513686, dtype=float32), 'eta1': Array(0.2707197, dtype=float32), 'eta2': Array(0.58231056, dtype=float32), 'eta3': Array(0.43208593, dtype=float32), 'k_a': Array(15.329325, dtype=float32), 'k_g': Array(23.053175, dtype=float32), 'k_p': Array(2.3432043, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.43988326, dtype=float32), 'nu': Array(0., dtype=float32)}
#   {'c_a': Array(0.05321252, dtype=float32), 'eta0': Array(0.2794881, dtype=float32), 'eta1': Array(0.2164086, dtype=float32), 'eta2': Array(0.26466832, dtype=float32), 'eta3': Array(0.3457098, dtype=float32), 'k_a': Array(18., dtype=float32), 'k_g': Array(19.97323, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0.8750802, dtype=float32), 'm': Array(0.03133471, dtype=float32), 'nu': Array(1.0456171, dtype=float32)}
#   {'c_a': Array(17.357302, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.13827045, dtype=float32), 'eta2': Array(0.9780529, dtype=float32), 'eta3': Array(0.09592229, dtype=float32), 'k_a': Array(16.52298, dtype=float32), 'k_g': Array(14.581233, dtype=float32), 'k_p': Array(3.4927404, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03261764, dtype=float32), 'nu': Array(13.237576, dtype=float32)}
#   {'c_a': Array(0.01658793, dtype=float32), 'eta0': Array(0.4681416, dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(0.15543135, dtype=float32), 'eta3': Array(0.14872728, dtype=float32), 'k_a': Array(15.578892, dtype=float32), 'k_g': Array(17.314678, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02611006, dtype=float32), 'nu': Array(7.219194, dtype=float32)}
#   {'c_a': Array(16.991438, dtype=float32), 'eta0': Array(0.176561, dtype=float32), 'eta1': Array(0.75894904, dtype=float32), 'eta2': Array(0., dtype=float32), 'eta3': Array(0.8501427, dtype=float32), 'k_a': Array(2.5760999, dtype=float32), 'k_g': Array(20.525908, dtype=float32), 'k_p': Array(2.3825965, dtype=float32), 'l_g': Array(0.00436187, dtype=float32), 'm': Array(0.37750193, dtype=float32), 'nu': Array(0.00917185, dtype=float32)}
#   {'c_a': Array(0.00853478, dtype=float32), 'eta0': Array(0., dtype=float32), 'eta1': Array(0.00010338, dtype=float32), 'eta2': Array(0.00135234, dtype=float32), 'eta3': Array(0.00240041, dtype=float32), 'k_a': Array(11.544637, dtype=float32), 'k_g': Array(15.410069, dtype=float32), 'k_p': Array(0., dtype=float32), 'l_g': Array(0.16026807, dtype=float32), 'm': Array(0.2935631, dtype=float32), 'nu': Array(0.06258675, dtype=float32)}
#   {'c_a': Array(19.844273, dtype=float32), 'eta0': Array(0.00966283, dtype=float32), 'eta1': Array(0.00981693, dtype=float32), 'eta2': Array(0.0096598, dtype=float32), 'eta3': Array(0.00976249, dtype=float32), 'k_a': Array(3.3457732, dtype=float32), 'k_g': Array(25.99406, dtype=float32), 'k_p': Array(3.99431, dtype=float32), 'l_g': Array(0.01204071, dtype=float32), 'm': Array(0.00226158, dtype=float32), 'nu': Array(17.427582, dtype=float32)}]
#  [{'c_a': Array(16.309063, dtype=float32), 'eta0': Array(0.67276543, dtype=float32), 'eta1': Array(0.38234806, dtype=float32), 'eta2': Array(0.5292154, dtype=float32), 'eta3': Array(0.24764545, dtype=float32), 'k_a': Array(12.984419, dtype=float32), 'k_g': Array(23.886677, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02599883, dtype=float32), 'nu': Array(21.255945, dtype=float32)}
#   {'key': nan}
#   {'c_a': Array(17.946817, dtype=float32), 'eta0': Array(0.67984796, dtype=float32), 'eta1': Array(1., dtype=float32), 'eta2': Array(0.34670097, dtype=float32), 'eta3': Array(0.3193678, dtype=float32), 'k_a': Array(0.79910034, dtype=float32), 'k_g': Array(14.001513, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.26242396, dtype=float32), 'nu': Array(1.6839283, dtype=float32)}
#   {'c_a': Array(18.637415, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(9.120772, dtype=float32), 'k_g': Array(16.975637, dtype=float32), 'k_p': Array(1.4681025, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.0359998, dtype=float32), 'nu': Array(16.85625, dtype=float32)}
#   {'c_a': Array(6.4369607, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.02704364, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0.871968, dtype=float32), 'k_a': Array(7.7116165, dtype=float32), 'k_g': Array(23.566496, dtype=float32), 'k_p': Array(0., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02323607, dtype=float32), 'nu': Array(14.802761, dtype=float32)}
#   {'key': nan}
#   {'c_a': Array(4.3688064, dtype=float32), 'eta0': Array(0.03084596, dtype=float32), 'eta1': Array(0.19861963, dtype=float32), 'eta2': Array(0., dtype=float32), 'eta3': Array(0.20822766, dtype=float32), 'k_a': Array(4.8250585, dtype=float32), 'k_g': Array(6.9031997, dtype=float32), 'k_p': Array(3.6322355, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.10349318, dtype=float32), 'nu': Array(0.41336757, dtype=float32)}
#   {'c_a': Array(12.5645895, dtype=float32), 'eta0': Array(0.30127192, dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(0., dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(13.362036, dtype=float32), 'k_g': Array(26., dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03180043, dtype=float32), 'nu': Array(15.620677, dtype=float32)}
#   {'c_a': Array(3.5134704, dtype=float32), 'eta0': Array(0.58526796, dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(0.6964063, dtype=float32), 'eta3': Array(0.06039616, dtype=float32), 'k_a': Array(18., dtype=float32), 'k_g': Array(21.069849, dtype=float32), 'k_p': Array(2.5853813, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03060111, dtype=float32), 'nu': Array(18.310507, dtype=float32)}
#   {'c_a': Array(5.9546194, dtype=float32), 'eta0': Array(0.6773582, dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(0.73954815, dtype=float32), 'eta3': Array(0.02919712, dtype=float32), 'k_a': Array(12.722733, dtype=float32), 'k_g': Array(20.907679, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03168527, dtype=float32), 'nu': Array(13.20353, dtype=float32)}]
#  [{'c_a': Array(0.02828524, dtype=float32), 'eta0': Array(0.42155662, dtype=float32), 'eta1': Array(0.42848203, dtype=float32), 'eta2': Array(0.4260965, dtype=float32), 'eta3': Array(0.4205056, dtype=float32), 'k_a': Array(18., dtype=float32), 'k_g': Array(20.046896, dtype=float32), 'k_p': Array(3.7466183, dtype=float32), 'l_g': Array(0.24151905, dtype=float32), 'm': Array(0.3067667, dtype=float32), 'nu': Array(1.8452026, dtype=float32)}
#   {'c_a': Array(0.00183176, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(1., dtype=float32), 'eta2': Array(0.92867947, dtype=float32), 'eta3': Array(0.94527364, dtype=float32), 'k_a': Array(15.399183, dtype=float32), 'k_g': Array(18.386166, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0.05446488, dtype=float32), 'm': Array(0.25427565, dtype=float32), 'nu': Array(1.371405, dtype=float32)}
#   {'c_a': Array(20., dtype=float32), 'eta0': Array(0.38628885, dtype=float32), 'eta1': Array(0.00310872, dtype=float32), 'eta2': Array(0., dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(15.4452305, dtype=float32), 'k_g': Array(22.294258, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02870066, dtype=float32), 'nu': Array(21.415604, dtype=float32)}
#   {'c_a': Array(13.152599, dtype=float32), 'eta0': Array(1., dtype=float32), 'eta1': Array(0.04780816, dtype=float32), 'eta2': Array(1., dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(9.010519, dtype=float32), 'k_g': Array(19.521795, dtype=float32), 'k_p': Array(3.877237, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.03636898, dtype=float32), 'nu': Array(21.694958, dtype=float32)}
#   {'c_a': Array(18.214384, dtype=float32), 'eta0': Array(0.72105354, dtype=float32), 'eta1': Array(0., dtype=float32), 'eta2': Array(0., dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(4.816029, dtype=float32), 'k_g': Array(14.288885, dtype=float32), 'k_p': Array(4., dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.02515572, dtype=float32), 'nu': Array(24.0364, dtype=float32)}
#   {'key': nan} {'key': nan} {'key': nan}
#   {'c_a': Array(4.4583683, dtype=float32), 'eta0': Array(0.00029962, dtype=float32), 'eta1': Array(0.00751914, dtype=float32), 'eta2': Array(0., dtype=float32), 'eta3': Array(0., dtype=float32), 'k_a': Array(8.197724, dtype=float32), 'k_g': Array(23.553028, dtype=float32), 'k_p': Array(0., dtype=float32), 'l_g': Array(0.27979428, dtype=float32), 'm': Array(0.39447933, dtype=float32), 'nu': Array(0.03139636, dtype=float32)}
#   {'c_a': Array(15.890634, dtype=float32), 'eta0': Array(0., dtype=float32), 'eta1': Array(0.37586197, dtype=float32), 'eta2': Array(0., dtype=float32), 'eta3': Array(0.26532823, dtype=float32), 'k_a': Array(4.5277963, dtype=float32), 'k_g': Array(20.15792, dtype=float32), 'k_p': Array(2.926302, dtype=float32), 'l_g': Array(0., dtype=float32), 'm': Array(0.4164079, dtype=float32), 'nu': Array(0.40595424, dtype=float32)}]]

# %%
def get_mse(params_sweep,orientation = 'var'):
    """
    Calculate the mean squared error (MSE) for each parameter
    """
    params_train_sweep = params_sweep[:,:,0]
    # Read the real parameters from the config file
    N,size,ls = read_config(["l_0","c_a","k_ij","k_j","k_a","m","c_damp","n_0","delta_t_m","it_m","pad"])
    l_0, c_a0, k_g0, k_p0, k_a0, m0, nu0, eta0, delta_t_m, it_m, pad = ls
    real_params = {'l_g':l_0,'k_g':k_g0,'k_p':k_p0,'k_a':k_a0,'m':m0,'nu':nu0,'c_a': c_a0 }
    real_params_eta = {'eta0':0,'eta1':0,'eta2':0,'eta3':0}
    if orientation == 'var':
        eta_arr = 1 - np.load('../data/SpringMassModel/FiberOrientation/fiber_orientation.npy')
    else:
        eta_arr = np.load('../data/SpringMassModel/FiberOrientation/fiber_orientation.npy')
        eta_arr[:,:] = orientation
        
    mse = {key: 0.0 for key in real_params}
    nmse = {key: 0.0 for key in real_params}
    
    for param in real_params:
        squared_errors = []
        for i in range(params_train_sweep.shape[0]):
            for j in range(params_train_sweep.shape[1]):
                if param in params_train_sweep[i, j]:
                    # Get the fitted value and calculate the squared error
                    i_grid,j_grid = 5 + i * 10, 5 + j * 10
                    eta0,eta1,eta2,eta3= eta_arr[i_grid-1,j_grid-1],eta_arr[i_grid-1,j_grid],eta_arr[i_grid,j_grid],eta_arr[i_grid,j_grid-1]
                    real_params_eta = {'eta0':eta0,'eta1':eta1,'eta2':eta2,'eta3':eta3}
                    real_params = {'l_g':l_0,'k_g':k_g0,'k_p':k_p0,'k_a':k_a0,'m':m0,'nu':nu0,'c_a': c_a0 }

                    squared_errors.append((params_train_sweep[i, j][param] - real_params[param]) ** 2)
        # Compute the mean of squared errors
        mse[param] = np.mean(squared_errors)
        nmse[param] = np.sqrt(mse[param] / (real_params[param] ** 2))
        
    mse_eta = {key: 0.0 for key in real_params_eta}
    nmse_eta = {key: 0.0 for key in real_params_eta}

    for params in real_params_eta:
        squared_errors = []
        for i in range(params_train_sweep.shape[0]):
            for j in range(params_train_sweep.shape[1]):
                if params in params_train_sweep[i, j]:
                    # Get the fitted value and calculate the squared error
                    i_grid,j_grid = 5 + i * 10, 5 + j * 10
                    eta0,eta1,eta2,eta3= eta_arr[i_grid-1,j_grid-1],eta_arr[i_grid-1,j_grid],eta_arr[i_grid,j_grid],eta_arr[i_grid,j_grid-1]
                    real_params_eta = {'eta0':eta0,'eta1':eta1,'eta2':eta2,'eta3':eta3}
                    real_params = {'l_g':l_0,'k_g':k_g0,'k_p':k_p0,'k_a':k_a0,'m':m0,'nu':nu0,'c_a': c_a0 }

                    squared_errors.append((params_train_sweep[i, j][params] - real_params_eta[params]) ** 2)
        # Compute the mean of squared errors
        mse_eta[params] = np.sqrt(np.mean(squared_errors))
    
    return mse, nmse, mse_eta

def get_eta_sweep(params_sweep,orientation = 'var'):
    params_train_sweep = params_sweep[:,:,0]
    loss = params_sweep[:,:,1]
    if orientation == 'var':
        eta_arr = 1 - np.load('../data/SpringMassModel/FiberOrientation/fiber_orientation.npy')
    else:
        eta_arr = np.load('../data/SpringMassModel/FiberOrientation/fiber_orientation.npy')
        eta_arr[:,:] = orientation

    eta0_real = np.full((10,10),np.nan)
    eta0_fit = np.full((10,10),np.nan)
    for i in range(10):
        for j in range(10):
            eta0_real[i,j] = eta_arr[5+i*10-1, 5+j*10-1]
            if 'eta0' in params_train_sweep[i,j]:
                eta0_fit[i,j] = params_train_sweep[i,j]['eta0']
            if type(loss[i,j]) == dict:
                loss[i,j] = np.nan
    eta0_err = np.abs(eta0_real - eta0_fit)

    return eta0_real, eta0_fit, eta0_err, loss

def replace_dicts_with_nan(arr):
    # Loop through all elements in the array
    for idx in np.ndindex(arr.shape):
        if isinstance(arr[idx], dict):  # Check if the element is a dictionary
            arr[idx] = np.nan  # Replace with np.na

# def get_best_stencil(params_sweep_var_stencil):
#     params_sweep_var_stencil_temp = params_sweep_var_stencil
#     # params_sweep_var_stencil_temp[:,:,:,1] = np.where(
#     #     np.vectorize(lambda x: isinstance(x, dict))(params_sweep_var_stencil_temp[:,:,:,1]),
#     #     np.nan,
#     #     params_sweep_var_stencil[:,:,:,1],
#     # )
#     # params_sweep_var_stencil_temp[:,:,:,1] =params_sweep_var_stencil[:,:,:,1].astype(float)

#     params_sweep_var_stencil_temp[:,:,:,1] = replace_dicts_with_nan(params_sweep_var_stencil_temp[:,:,:,1])
#     # Step 1: Extract the loss values from b
#     loss_values = params_sweep_var_stencil_temp[:,:,:,1]  # This gives you the 10x10 loss matrix
#     print(loss_values.shape)
#     # Step 2: Find the index of the minimum loss
#     min_loss_index = np.nanargmin(loss_values,axis=2)
#     # Step 3: Get the corresponding 'a' arrays
#     # Use the min_loss_index to extract the relevant 'a' arrays from params_sweep_var_stencil
#     best_k = np.full((10,10,2),np.nan)
#     best_k[min_loss_index,1] = params_sweep_var_stencil[:,:,:,1][min_loss_index]

#     min_loss = np.reshape(params_sweep_var_stencil[np.arange(10), np.arange(10), min_loss_index, 1],(10,10,1))
#     min_eta = np.reshape(params_sweep_var_stencil[np.arange(10), np.arange(10), min_loss_index, 0],(10,10,1))
#     print(min_loss_index)
#     params_sweep_var_stencil = np.concatenate((min_eta,min_loss),axis=2)
#     return params_sweep_var_stencil

mse_eta05, nmse_eta05, mse_eta_eta05 = get_mse(params_sweep_eta05,orientation=0.5)
mse_var, nmse_var, mse_eta_var = get_mse(params_sweep_var)

# %%
param_keys = ['$l_g$', '$k_g$', '$k_p$', '$k_a$', '$m$', r'$\nu$', '$c_a$']

# %%
#make diagramm of nmse and mse_eta next to each other. both bars should have the same y axis
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].bar(param_keys, nmse_eta05.values())
ax[0].set_ylim((0,1))
ax[0].set_ylabel('NRMSE')
eta_labels = ['$\eta_0$','$\eta_1$','$\eta_2$','$\eta_3$']
ax[1].bar(eta_labels, mse_eta_eta05.values())
ax[1].set_ylim((0,1))
fig.suptitle('Fitted with NNR, homogeneous $\eta$-distribution ($\eta=0.5$)', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')
ax[1].set_ylabel('RMSE')
plt.savefig('../../figures/results/etasweep_rec_mse_eta05.png')

# %%
fig,ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].bar(param_keys, nmse_var.values())
ax[0].set_ylim((0,1))
ax[0].set_ylabel('NRMSE')
ax[1].bar(eta_labels, mse_eta_var.values())
#same y axis
ax[1].set_ylim((0,1))
ax[1].set_ylabel('RMSE')
fig.suptitle('Fitted with NNR, non homogeneous $\eta$-distribution', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')
plt.savefig('../../figures/results/etasweep_rec_mse_var.png')

# %%
eta0_real_eta05, eta0_fit_eta05, eta0_err_eta05, loss_eta05 = get_eta_sweep(params_sweep_eta05,orientation=0.5)
loss_eta05 = np.array(loss_eta05,dtype=float)
eta0_real_var, eta0_fit_var, eta0_err_var, loss_var = get_eta_sweep(params_sweep_var)
loss_var = np.array(loss_var,dtype=float)

# %%
# Plotting
fig, ax = plt.subplots(2, 2, figsize=(12, 12))

# Real eta0
im = ax[0, 0].imshow(eta0_real_eta05, vmin=0, vmax=1)
ax[0, 0].set_title('Real $\eta_0$')
fig.colorbar(im, ax=ax[0, 0])
ax[0, 0].annotate('a)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Fitted eta0
im = ax[0, 1].imshow(eta0_fit_eta05, vmin=0, vmax=1)
ax[0, 1].set_title('Fitted $\eta_0$')
fig.colorbar(im, ax=ax[0, 1])
ax[0, 1].annotate('b)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Error eta0
im = ax[1, 0].imshow(eta0_err_eta05, vmin=0, vmax=1)
ax[1, 0].set_title('Error $\eta_0$')
fig.colorbar(im, ax=ax[1, 0])
ax[1, 0].annotate('c)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Loss
im = ax[1, 1].imshow(loss_eta05 * 10**5)
ax[1, 1].set_title('Loss $\cdot 10^5$')
fig.colorbar(im, ax=ax[1, 1])
ax[1, 1].annotate('d)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')


fig.suptitle('Fitted with NNR, homogeneous $\eta$-distribution ($\eta=0.5$)', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')
# Adjust layout
plt.tight_layout()
plt.savefig('../../figures/results/etasweep_rec_eta05.png')
plt.show()

# %%
# Plotting
fig, ax = plt.subplots(2, 2, figsize=(12, 12))

# Real eta0
im = ax[0, 0].imshow(eta0_real_var, vmin=0, vmax=1)
ax[0, 0].set_title('Real $\eta_0$')
fig.colorbar(im, ax=ax[0, 0])
ax[0, 0].annotate('a)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Fitted eta0
im = ax[0, 1].imshow(eta0_fit_var, vmin=0, vmax=1)
ax[0, 1].set_title('Fitted $\eta_0$')
fig.colorbar(im, ax=ax[0, 1])
ax[0, 1].annotate('b)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Error eta0
im = ax[1, 0].imshow(eta0_err_var, vmin=0, vmax=1)
ax[1, 0].set_title('Error $\eta_0$')
fig.colorbar(im, ax=ax[1, 0])
ax[1, 0].annotate('c)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Loss
im = ax[1, 1].imshow(loss_var * 10**5)
ax[1, 1].set_title('Loss $\cdot 10^5$')
fig.colorbar(im, ax=ax[1, 1])
ax[1, 1].annotate('d)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

fig.suptitle('Fitted with NNR, non homogeneous $\eta$-distribution', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')
# Adjust layout
plt.tight_layout()
plt.savefig('../../figures/results/etasweep_rec_eta_var.png')
plt.show()

# %%
# make plot of two heatmaps
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Real eta0
im = ax[0].imshow(eta0_real_var, vmin=0, vmax=1)
ax[0].set_title('Ground truth $\eta$')
fig.colorbar(im, ax=ax[0])

# Fitted eta0
im = ax[1].imshow(eta0_fit_var, vmin=0, vmax=1)
ax[1].set_title('Reconstructed $\eta$')
fig.colorbar(im, ax=ax[1])

fig.suptitle('Reconstructing Muscle Fiber Orientation by Fitting Single Mass Points.', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')
# Adjust layout
plt.tight_layout()
plt.savefig('../../figures/results/etasweep_rec_eta05_poster.png',dpi=300)
plt.show()

# %%
def get_best_stencil(params_sweep_var_stencil):

    params_sweep_var_stencil_temp = params_sweep_var_stencil
    params_sweep_var_stencil_temp[:,:,:,1] = np.where(
        np.vectorize(lambda x: isinstance(x, dict))(params_sweep_var_stencil_temp[:,:,:,1]),
        np.nan,
        params_sweep_var_stencil[:,:,:,1],
    )
    params_sweep_var_stencil_temp[:,:,:,1] =params_sweep_var_stencil[:,:,:,1]#.astype(float)
    # Step 1: Extract the loss values from b
    loss_values = params_sweep_var_stencil_temp[:,:,:,1]  # This gives you the 10x10 loss matrix
    param_values = params_sweep_var_stencil_temp[:,:,:,0]
    
    best_k = np.full((10,10,2),np.nan,dtype = object)

    for i in range(10):
        for j in range(10):
            if all(x != x for x in loss_values[i,j,:]):
                pass
            
            else:
            
                best_k[i,j,1] = loss_values[i,j,:][np.nanargmin(loss_values[i,j,:])]
                best_k[i,j,0] = param_values[i,j,:][np.nanargmin(loss_values[i,j,:])]
    best_k = np.array([
    [[{'key': np.nan} if isinstance(x, float) and np.isnan(x) else x for x in pair]
        for pair in row]
    for row in best_k], dtype=object) 
    return best_k

mse_eta05, nmse_eta05, mse_eta_eta05 = get_mse(params_sweep_eta05,orientation=0.5)
mse_var, nmse_var, mse_eta_var = get_mse(params_sweep_var)

# %%
params_sweep_var_stencil = np.load('../data/SpringMassModel/EtaSweep/eta_sweepT_Stencil_l_var_1.npy',allow_pickle=True)
params_sweep_var_stencil = get_best_stencil(params_sweep_var_stencil)

params_sweep_eta05_stencil = np.load('../data/SpringMassModel/EtaSweep/eta_sweepT_Stencil_l_eta05_1.npy',allow_pickle=True)
params_sweep_eta05_stencil = get_best_stencil(params_sweep_eta05_stencil)
print(params_sweep_var_stencil[0,0,1])
# Out:
# 8.502212978100943e-08

# %%
mse_var_stencil, nmse_var_stencil, mse_eta_var_stencil = get_mse(params_sweep_var_stencil)
mse_eta05_stencil, nmse_eta05_stencil, mse_eta_eta05_stencil = get_mse(params_sweep_eta05_stencil,orientation=0.5)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].bar(param_keys, nmse_eta05_stencil.values())
ax[0].set_ylim((0,1))
ax[0].set_ylabel('NRMSE')
eta_labels = ['$\eta_0$','$\eta_1$','$\eta_2$','$\eta_3$']
ax[1].bar(eta_labels, mse_eta_eta05_stencil.values())
ax[1].set_ylim((0,1))
ax[1].set_ylabel('RMSE')
fig.suptitle('Fitted with Stencil, homogeneous $\eta$-distribution ($\eta=0.5$)', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')
plt.savefig('../../figures/results/etasweep_stencil_mse_eta05.png')

# %%
fig,ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].bar(param_keys, nmse_var_stencil.values())
ax[0].set_ylim((0,1))
ax[0].set_ylabel('NRMSE')
ax[1].bar(eta_labels, mse_eta_var_stencil.values())
#same y axis
ax[1].set_ylim((0,1))
ax[1].set_ylabel('RMSE')
fig.suptitle('Fitted with Stencil, non homogeneous $\eta$-distribution', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')
plt.savefig('../../figures/results/etasweep_stencil_mse_var.png')

# %%
eta0_real_eta05_Stencil, eta0_fit_eta05_Stencil, eta0_err_eta05_Stencil, loss_eta05_Stencil = get_eta_sweep(params_sweep_eta05_stencil,orientation=0.5)
loss_eta05_Stencil = np.array(loss_eta05_Stencil,dtype=float)
eta0_real_var_Stencil, eta0_fit_var_Stencil, eta0_err_var_Stencil, loss_var_Stencil = get_eta_sweep(params_sweep_var_stencil)
loss_var_Stencil = np.array(loss_var_Stencil,dtype=float)

# %%
# Plotting
fig, ax = plt.subplots(2, 2, figsize=(12, 12))

# Real eta0
im = ax[0, 0].imshow(eta0_real_eta05_Stencil, vmin=0, vmax=1)
ax[0, 0].set_title('Real $\eta_0$')
fig.colorbar(im, ax=ax[0, 0])
ax[0, 0].annotate('a)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Fitted eta0
im = ax[0, 1].imshow(eta0_fit_eta05_Stencil, vmin=0, vmax=1)
ax[0, 1].set_title('Fitted $\eta_0$')
fig.colorbar(im, ax=ax[0, 1])
ax[0, 1].annotate('b)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Error eta0
im = ax[1, 0].imshow(eta0_err_eta05_Stencil, vmin=0, vmax=1)
ax[1, 0].set_title('Error $\eta_0$')
fig.colorbar(im, ax=ax[1, 0])
ax[1, 0].annotate('c)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Loss
im = ax[1, 1].imshow(loss_eta05_Stencil * 10**5)
ax[1, 1].set_title('Loss $\cdot 10^5$')
fig.colorbar(im, ax=ax[1, 1])
ax[1, 1].annotate('d)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

fig.suptitle('Fitted with $T_a$-stencil, homogeneous $\eta$-distribution ($\eta=0.5$)', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')
# Adjust layout
plt.tight_layout()
plt.savefig('../../figures/results/etasweep_stencil_eta05.png')
plt.show()

# %%
# Plotting
fig, ax = plt.subplots(2, 2, figsize=(12, 12))

# Real eta0
im = ax[0, 0].imshow(eta0_real_var_Stencil, vmin=0, vmax=1)
ax[0, 0].set_title('Real $\eta_0$')
fig.colorbar(im, ax=ax[0, 0])
ax[0, 0].annotate('a)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Fitted eta0
im = ax[0, 1].imshow(eta0_fit_var_Stencil, vmin=0, vmax=1)
ax[0, 1].set_title('Fitted $\eta_0$')
fig.colorbar(im, ax=ax[0, 1])
ax[0, 1].annotate('b)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Error eta0
im = ax[1, 0].imshow(eta0_err_var_Stencil, vmin=0, vmax=1)
ax[1, 0].set_title('Error $\eta_0$')
fig.colorbar(im, ax=ax[1, 0])
ax[1, 0].annotate('c)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

# Loss
im = ax[1, 1].imshow(loss_var_Stencil * 10**5)
ax[1, 1].set_title('Loss $\cdot 10^5$')
fig.colorbar(im, ax=ax[1, 1])
ax[1, 1].annotate('d)', xy=(-.1, 1.1), xycoords='axes fraction', fontsize=plt.rcParams['axes.titlesize'], 
                  fontweight='normal', ha='left', va='top')

fig.suptitle('Fitted with $T_a$-stencil, non homogeneous $\eta$-distribution', fontsize=plt.rcParams['axes.titlesize'], fontweight='bold')
# Adjust layout
plt.tight_layout()
plt.savefig('../../figures/results/etasweep_stencil_eta_var.png')
plt.show()
